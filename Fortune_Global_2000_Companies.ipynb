# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandini37/Nandini37/blob/main/Fortune_Global_2000_Companies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fortune Global 2000 Companies (2021)
#
# **Fortune Global 2000 Companies with Sales, Profits, Assets, Market Value**
# <br>
# Hii...this is my first python project.

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd #data processing
import numpy as np #linear algebra
import io
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # **DATA EXTRACTION**
# **Uploading the File**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6536622d-e473-4f3e-a9dd-c16b8597f2c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6536622d-e473-4f3e-a9dd-c16b8597f2c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fortune_2000_in_2021.csv to fortune_2000_in_2021.csv

# %% [markdown]
# **Reading the file**

# %%
df = pd.read_csv(io.BytesIO(uploaded["fortune_2000_in_2021.csv"]))
df
# Out:
#       Rank                                      Name  ...      Assets Market Value
# 0        1                                      ICBC  ...  $4,914.7 B     $249.5 B
# 1        2                            JPMorgan Chase  ...  $3,689.3 B     $464.8 B
# 2        3                        Berkshire Hathaway  ...    $873.7 B     $624.4 B
# 3        4                   China Construction Bank  ...  $4,301.7 B     $210.4 B
# 4        5  Saudi Arabian Oil Company (Saudi Aramco)  ...    $510.3 B   $1,897.2 B
# ...    ...                                       ...  ...         ...          ...
# 1995  1996                                     JTEKT  ...       $12 B       $3.5 B
# 1996  1997                 Insurance Australia Group  ...       $25 B       $9.3 B
# 1997  1997                         Sumec Corporation  ...      $7.1 B       $1.3 B
# 1998  1999                               Gold Fields  ...      $7.5 B       $8.9 B
# ...

# %%
df.head()
# Out:
#    Rank                                      Name  ...      Assets Market Value
# 0     1                                      ICBC  ...  $4,914.7 B     $249.5 B
# 1     2                            JPMorgan Chase  ...  $3,689.3 B     $464.8 B
# 2     3                        Berkshire Hathaway  ...    $873.7 B     $624.4 B
# 3     4                   China Construction Bank  ...  $4,301.7 B     $210.4 B
# 4     5  Saudi Arabian Oil Company (Saudi Aramco)  ...    $510.3 B   $1,897.2 B
#
# [5 rows x 7 columns]

# %%
df.tail()
# Out:
#       Rank                       Name  ...  Assets Market Value
# 1995  1996                      JTEKT  ...   $12 B       $3.5 B
# 1996  1997  Insurance Australia Group  ...   $25 B       $9.3 B
# 1997  1997          Sumec Corporation  ...  $7.1 B       $1.3 B
# 1998  1999                Gold Fields  ...  $7.5 B       $8.9 B
# 1999  1999                     Paycom  ...  $2.6 B        $24 B
#
# [5 rows x 7 columns]

# %%
df.describe()
# Out:
#             Rank
# count  2000.0000
# mean   1000.3135
# std     577.4019
# min       1.0000
# 25%     500.7500
# 50%    1000.0000
# 75%    1500.2500
# max    1999.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2000 non-null   int64
#  1   Name          2000 non-null   object
#  2   Country       2000 non-null   object
#  3   Sales         2000 non-null   object
#  4   Profit        2000 non-null   object
#  5   Assets        1999 non-null   object
#  6   Market Value  2000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 109.5+ KB

# %%
df.dropna(inplace= True)
df.info()
#drop missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          1999 non-null   int64
#  1   Name          1999 non-null   object
#  2   Country       1999 non-null   object
#  3   Sales         1999 non-null   float64
#  4   Profit        1999 non-null   float64
#  5   Assets        1999 non-null   float64
#  6   Market Value  1999 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 124.9+ KB

# %%
df.describe(include='object')
# Out:
#            Name        Country Market Value
# count      1999           1999         1999
# unique     1999             61          759
# top     Almarai  United States       $4.7 B
# freq          1            590           13

# %% [markdown]
# # Explatoratory Data Analysis(EDA)

# %%
df['Country']
# Out:
# 0               China
# 1       United States
# 2       United States
# 3               China
# 4        Saudi Arabia
#             ...
# 1995            Japan
# 1996        Australia
# 1997            China
# 1998     South Africa
# 1999    United States
# Name: Country, Length: 1999, dtype: object

# %%
df['Market Value'].unique()
# Out:
# array(['$249.5 B', '$464.8 B', '$624.4 B', '$210.4 B', '$1,897.2 B',
#        '$2,252.3 B', '$336.3 B', '$211.2 B', '$140.1 B', '$1,711.8 B',
#        '$510.5 B', '$219.2 B', '$1,538.9 B', '$116.7 B', '$1,966.6 B',
#        '$151.2 B', '$147.2 B', '$396.1 B', '$181.5 B', '$241.3 B',
#        '$369.6 B', '$192.8 B', '$657.5 B', '$108 B', '$252.4 B',
#        '$116.5 B', '$163.1 B', '$112.4 B', '$773.8 B', '$79.1 B',
#        '$123.9 B', '$134.9 B', '$870.5 B', '$427.1 B', '$137.3 B',
#        '$263.7 B', '$99.6 B', '$135 B', '$333.2 B', '$120.3 B', '$99.2 B',
#        '$120.6 B', '$96.7 B', '$91.6 B', '$117.6 B', '$338 B', '$84.6 B',
#        '$82.6 B', '$57.3 B', '$66.5 B', '$85.7 B', '$69.7 B', '$87.7 B',
#        '$67.8 B', '$153.7 B', '$164.9 B', '$47.9 B', '$215.2 B',
#        '$119.4 B', '$287.1 B', '$69.8 B', '$55.8 B', '$66.7 B',
#        '$380.3 B', '$198.6 B', '$558.1 B', '$352.8 B', '$47.4 B',
#        '$139.8 B', '$199.2 B', '$227.7 B', '$127.4 B', '$105.4 B',
# ...

# %%
df.head()
# Out:
#    Rank                                      Name  ...  Assets  Market Value
# 0     1                                      ICBC  ...  4914.7      $249.5 B
# 1     2                            JPMorgan Chase  ...  3689.3      $464.8 B
# 2     3                        Berkshire Hathaway  ...   873.7      $624.4 B
# 3     4                   China Construction Bank  ...  4301.7      $210.4 B
# 4     5  Saudi Arabian Oil Company (Saudi Aramco)  ...   510.3    $1,897.2 B
#
# [5 rows x 7 columns]

# %%
#re-format market value column
df['Market Value'] = [float(str(i).replace(',', '').replace('$', '').replace('B', '').replace('M', '')) 
for i in df['Market Value']]
df.head()
#Here we  removed "," ; "$" ; "B" ; "M" IN Market Value column and converted it to float
# Out:
#    Rank                                      Name  ...  Assets  Market Value
# 0     1                                      ICBC  ...  4914.7         249.5
# 1     2                            JPMorgan Chase  ...  3689.3         464.8
# 2     3                        Berkshire Hathaway  ...   873.7         624.4
# 3     4                   China Construction Bank  ...  4301.7         210.4
# 4     5  Saudi Arabian Oil Company (Saudi Aramco)  ...   510.3        1897.2
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          1999 non-null   int64
#  1   Name          1999 non-null   object
#  2   Country       1999 non-null   object
#  3   Sales         1999 non-null   float64
#  4   Profit        1999 non-null   float64
#  5   Assets        1999 non-null   float64
#  6   Market Value  1999 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 124.9+ KB

# %%
df.describe()
# Out:
#               Rank        Sales       Profit       Assets  Market Value
# count  1999.000000  1999.000000  1999.000000  1999.000000   1999.000000
# mean    999.846923    38.761431   233.575338   112.569135     50.703252
# std     577.169137   117.220006   362.398066   346.731410    139.823639
# min       1.000000     1.000000  -997.200000     1.000000      1.000000
# 25%     500.500000     5.000000     1.500000    13.350000      8.700000
# 50%     999.000000    10.500000    87.800000    30.500000     18.500000
# 75%    1499.500000    22.100000   516.300000    73.700000     39.150000
# max    1999.000000   960.000000   996.200000  4914.700000   2252.300000

# %%
print('DataFrame Shape: ',df.shape)
# Out:
# DataFrame Shape:  (1999, 7)

# %% [markdown]
# # **Data Analyzing**

# %%
df.corr()
#Checking Coorelation of each variable
# Out:
#                   Rank     Sales    Profit    Assets  Market Value
# Rank          1.000000  0.068278  0.183027 -0.335371     -0.158449
# Sales         0.068278  1.000000 -0.143211  0.069443      0.295642
# Profit        0.183027 -0.143211  1.000000 -0.143169     -0.130537
# Assets       -0.335371  0.069443 -0.143169  1.000000      0.108960
# Market Value -0.158449  0.295642 -0.130537  0.108960      1.000000

# %%
#visualize correlation of each variable using pearson correlation
sns.heatmap(df.corr(), annot = True, cmap = 'YlGnBu')
plt.title('Pearson Correlation', fontsize = 17, pad = 12, color = 'maroon')
plt.show()

# %%
df.boxplot(column=["Sales", "Profit", "Market Value", "Assets"])
plt.ylabel('Count', fontsize = 12)
plt.show()

# %% [markdown]
# **Checking Companies Count From Country**

# %%
df.Country.value_counts().head(20)
# Out:
# United States     590
# China             291
# Japan             215
# United Kingdom     66
# South Korea        62
# Hong Kong          59
# Canada             56
# Germany            54
# France             53
# India              50
# Taiwan             45
# Switzerland        42
# Sweden             32
# Australia          31
# Russia             24
# Italy              23
# Brazil             21
# Spain              21
# Netherlands        20
# Ireland            18
# Name: Country, dtype: int64

# %%
#Checking Company Count for India
df_India = df[df.Country == 'India']
df_India.shape
df_India.head()
# Out:
#      Rank                 Name Country  Sales  Profit  Assets  Market Value
# 55     55  Reliance Industries   India   61.2     5.7   166.3         164.9
# 109   110  State Bank of India   India   50.6     3.1   638.1          40.8
# 115   116            HDFC Bank   India   20.7     4.1   233.6         105.9
# 181   182           ICICI Bank   India   21.3     2.0   207.9          52.7
# 219   220                 HDFC   India   16.2     2.4   105.0          62.4

# %%
#analyze of company and country based on rank
company_rank = pd.pivot_table(df, index = ['Rank', 'Name', 'Country'])
company_rank
# Out:
#                                                              Assets  ...  Sales
# Rank Name                                     Country                ...
# 1    ICBC                                     China          4914.7  ...  190.5
# 2    JPMorgan Chase                           United States  3689.3  ...  136.2
# 3    Berkshire Hathaway                       United States   873.7  ...  245.5
# 4    China Construction Bank                  China          4301.7  ...  173.5
# 5    Saudi Arabian Oil Company (Saudi Aramco) Saudi Arabia    510.3  ...  229.7
# ...                                                             ...  ...    ...
# 1996 JTEKT                                    Japan            12.0  ...   13.1
# 1997 Insurance Australia Group                Australia        25.0  ...    5.4
#      Sumec Corporation                        China             7.1  ...   13.0
# 1999 Gold Fields                              South Africa      7.5  ...    3.9
# ...

# %%
dfGlobal=(df.pivot_table(index="Country",values=["Market Value"],aggfunc="sum").sort_values("Market Value",ascending=False).iloc[:5])
globalSum=df["Market Value"].sum()
dfGlobalShare=np.round((dfGlobal/globalSum)*100)
othersShare=100-dfGlobalShare.sum()
dfGlobalShare.loc[len(dfGlobalShare.index)]=[float(othersShare)]
dfGlobalShare.rename(index={5:'Others'},inplace=True)

dfGlobalShare.index

labels =dfGlobalShare.index
sizes = dfGlobalShare["Market Value"]
explode = (0,0,0,0,0,0.05)  
colors = ['#781C68','#3FA796','#8267BE','#502064','#F14A16','#95CD41']

plt.pie(sizes, explode=explode, labels=labels,autopct='%1.0f%%', shadow=False, startangle=90, colors=colors)

plt.title("Percentage of Market Value of top 5 Countries", fontsize=16)
plt.show()

# %% [markdown]
# Conclusion: 40% of Fortune 2000 listed Companies are from USA followed by Japan and then followed by China.

# %%
dfMarket=df.sort_values(by="Market Value",ascending=False).iloc[:10]

fig,ax = plt.subplots()
sns.barplot(x="Market Value", y="Name", data=dfMarket, palette='magma')
plt.xlabel("Market Value",fontsize=14)
plt.ylabel("Company",fontsize=14)
plt.title("Top 10 Companies based on Market Value", fontsize=16)
sns.set(rc={'figure.figsize':(10,10)})
plt.show()

# %% [markdown]
# Conclusion: Top 3 Companies based on Market Value is Apple, Microsoft and Saudi Arabian Oil Company.
